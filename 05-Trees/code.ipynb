# %% [markdown]
# # Gradient Boosting Playground

# %% [markdown]
# I've written a function for you to do some simple exploring of the gradient boosting hyperparameters.  The purpose of this exercise is to gain and intuitive understanding of the GB hyperparameters for different types of data.  Questions 1-5 are a guide for your own exploration.
#
# Make sure that the file `playground.py` is in the working directory, then import the `gb_playground` function:
# ```
# from playground import gb_playground
# ```
# Alternatively, you could copy and paste the relevant functions into your notebook or python code.
#
# This function isn't super flexible, but hopefully it will be useful to help you understand how the hyperparameters work.
#
#
#
# You can change the following arguments:
#
# * Data generation parameters:
#     * `dataset`:  Can be "blobs", "moons", or "circles".  These come from the scikit-learn toy datasets.
#     * `noise`: (default is 0.2).  This controls how much noise is in the data.  Keep this value between 0.1 and 0.4.
#     * `n_samples`: (default is 1000). Sample size.
#     * `random_state`: (default is 307).
#
# * Model hyperparameters:
# dataset, n_estimators=100, learning_rate=.1, max_depth=3, noise=.2, n_samples=1000, random_state=307
#     * `n_estimators`: (default is 100).  Number of estimators
#     * `max_depth`: (default is 3). Maximum tree depth of base learner
#     * `learning_rate`: (default is 0.1).

# %%
from playground import gb_playground

# %% [markdown]
# 1. **Number of estimators.** Compare the decision boundary, the training accuracy, and the test accuracy using n_estimators=50, n_estimators=100, and n_estimators=500 for each dataset using noise=0.3 and all other parameters left as defaults.
#
# How does changing the number of estimators affect under- and overfitting? Is the effect the same for all the datasets?

# %%
# Example usage 
gb_playground(dataset='circles',  noise=.25, n_estimators=200, learning_rate=.01, max_depth=None)

# %% [markdown]
# 2. **Learning rate.** Compare the decision boundary, the training accuracy, and the test accuracy using learning_rate=.01, learning_rate=.1, and learning_rate=1 for each dataset using noise=0.3 and all other parameters left as defaults.
#
# How does changing the learning rate affect under- and overfitting? Is the effect the same for all the datasets?

# %% [markdown]
# 3. **Trade-off between learning rate and number of estimators.** For this problem, use the "moons" dat with noise=0.3. Using a learning rate of 0.75, adjust the number of estimators used until you get comparable performance with a model that uses learning_rate=.1 and n_estimators=100.

# %% [markdown]
# 4. **Maximum depth.** Compare the decision boundary, the training accuracy, and the test accuracy using max_depth=1, max_depth=3, and max_depth=None for each dataset using noise=0.3 and all other parameters left as defaults.
# How does changing the maximum depth of individual decision trees affect under- and overfitting? Is the effect the same for all the datasets?
