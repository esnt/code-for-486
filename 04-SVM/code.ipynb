# %% [markdown]
# # SVM Playground

# %% [markdown]
# I've written a function for you to do some simple exploring of the SVM hyperparameters.  The purpose of this exercise is to gain and intuitive understanding of the SVM hyperparameters for different types of data.  Questions 1-5 are a guide for your own exploration.
#
# Make sure that the file `playground.py` is in the working directory, then import the `svm_playground` function:
# ```
# from playground import svm_playground
# ```
# Alternatively, you could copy and paste the relevant functions into your notebook or python code.
#
# This function isn't super flexible, but hopefully it will be useful to help you understand how the hyperparameters work.
#
#
#
# You can change the following arguments:
#
# * Data generation parameters:
#     * `dataset`:  Can be "blobs", "moons", or "circles".  These come from the scikit-learn toy datasets.
#     * `noise`: (default is 0.2).  This controls how much noise is in the data.  Keep this value between 0.1 and 0.4.
#     * `n_samples`: (default is 1000). Sample size.
#     * `random_state`: (default is 307).
#
# * Model hyperparameters:
#     * `kernel`: (default is 'rbf').  Common kernels are "linear", "poly", "rbf". See [sklearn.svm.SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) for list of possible kernels and [kernel functions documentation](https://scikit-learn.org/stable/modules/svm.html#svm-kernels) for definition of kernels.  (*At this time, the "poly" kernel doesn't seem to be plotting correctly.*)
#     * `C`: (default is 1.0). Regularization parameter.  The strength of regularization is inversely proportional to C.
#     * `gamma`: (default is "scale"). Kernel coefficient.  See [sklearn.svm.SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html). *The default of `gamma="scale"` means that 1 / (n_features * X.var()) is used as the value for gamma*.
#     * `degree`: (default is 3). Degree of polynomial kernel function.  Ignored by all kernels except "poly".

# %%
from playground import svm_playground

# %% [markdown]
# 1. **Kernel Types**. Compare the decision boundary generated by kernels `linear` and `rbf` (with all other defaults) for each of the datasets ("blobs", "moons", and "circles").
#
# Which kernel works best for each of the datasets?

# %%
# Example usage 
svm_playground(dataset='circles', kernel='rbf', noise=.25, C=100, gamma=.1)

# %% [markdown]
# 2. **Gamma in RBF kernel**. Compare the decision boundary, the training accuracy, and the test accuracy using `gamma=0.1`, `gamma=1`, and `gamma=20` for each dataset using `noise=0.3`. Use the `rbf` kernel with all other parameters left as the default.
#
# How does changing the value of gamma affect under- and overfitting?  Is the effect the same for all the datasets?

# %% [markdown]
# 3. **Noise in the data**. Repeat the previous exercise using `noise=0.15`.
#
# How does changing the variability in the data affect under- and overfitting? Is the effect the same for all the datasets?

# %% [markdown]
# 4. **Regularization parameter**. Compare the decision boundary, the training accuracy, and the test accuracy using a small value of "C" (`C=0.01` or `C=.1`), a medium value of "C" (`C=1` or `C=5`), and large value of "C" (`C=10` or `C=20`) for each dataset using `noise=0.3`.  Use the `rbf` kernel with all other parameters left as the default.
#
# How does changing the variability in the data affect under- and overfitting? Is the effect the same for all the datasets?

# %% [markdown]
# 5. **Sample size**.  See how changing the sample size (`n_samples`) affects the results from the previous exercises.
